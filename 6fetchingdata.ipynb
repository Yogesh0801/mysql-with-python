# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)
mycursor = mydb.cursor()
sql = "select * from students"
mycursor.execute(sql)
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)
# (5, 'sachin', '10th', 'sachin@gmail.com', 783267670)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)
# (7, 'abhishek', '10th', 'abhishek@gmail.com', 783267670)

# %%
mycursor= mydb.cursor()
sql = "select * from students order by name desc"
mycursor.execute(sql)
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)
# (5, 'sachin', '10th', 'sachin@gmail.com', 783267670)
# (7, 'abhishek', '10th', 'abhishek@gmail.com', 783267670)

# %%
mycursor= mydb.cursor()
sql = "select * from students order by phone desc"
mycursor.execute(sql)
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)
# (5, 'sachin', '10th', 'sachin@gmail.com', 783267670)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)
# (7, 'abhishek', '10th', 'abhishek@gmail.com', 783267670)

# %% [markdown]
# # limit

# %%
mycursor= mydb.cursor()
sql = "select * from students limit 0,4"
mycursor.execute(sql)
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)
# (5, 'sachin', '10th', 'sachin@gmail.com', 783267670)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)

# %% [markdown]
# ### fetching data

# %%
mydb = mysql.connector.connect(
  host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)
mycursor = mydb.cursor()
sql= """select * from students where name=%s"""
name = input("Enter the name to search: ")
mycursor.execute(sql, (name,))
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)

# %%
mycursor = mydb.cursor()
sql= """select * from students where name like %s"""
name = input("Enter the name to search: ")
mycursor.execute(sql, (f"%{name}%",))
myresult = mycursor.fetchall()
for x in myresult:
    print(x)
# Out:
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)
