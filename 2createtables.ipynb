# %%
import mysql.connector
mydb = mysql.connector.connect(
  host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)
mycursor = mydb.cursor()

mycursor.execute("CREATE TABLE students (rollno INT primary key auto_increment,name VARCHAR(255), class VARCHAR(255),email VARCHAR(255),phone int)")

# %%
mydb = mysql.connector.connect(
  host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)
mycursor = mydb.cursor()
mycursor.execute("show tables")
for x in mycursor:  print(x)
# Out:
# ('students',)

# %%
mydb = mysql.connector.connect(
  host="localhost",
    user="root",
    password="root",
    database="mydatabase"
)
mycursor = mydb.cursor()
mycursor.execute("select * from students")
for x in mycursor:  print(x)
