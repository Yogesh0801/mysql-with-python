# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user = "root",
    password = "root",
    database = "mydatabase")
mycursor = mydb.cursor()

sql = """insert into students
         set name = %s,
         class = %s,
         email = %s,
         phone = %s"""
         
values = ("yogesh", "10th", "yb@gmail.com", 783267670)
mycursor.execute(sql, values)
mydb.commit()
print("Record inserted successfully")
# Out:
# Record inserted successfully

# %%
mycursor.execute("select*from students")
for x in mycursor:  print(x)
# Out:
# (1, 'yogesh', '10th', 'yb@gmail.com', 78323)
# (2, 'yogesh', '10th', 'yb@gmail.com', 783236767)
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)

# %%
values = [("sagar", "10th", "sag@gmail.com", 783267670),
          ("sachin", "10th", "sachin@gmail.com", 783267670),
          ("satyarth", "10th", "satyarth@gmail.com", 783267670),
          ("abhishek", "10th", "abhishek@gmail.com", 783267670)]
mycursor.executemany(sql, values)
mydb.commit()
print("Records inserted successfully")
# Out:
# Records inserted successfully

# %%
mycursor.execute("select*from students")
for x in mycursor:  print(x)
# Out:
# (1, 'yogesh', '10th', 'yb@gmail.com', 78323)
# (2, 'yogesh', '10th', 'yb@gmail.com', 783236767)
# (3, 'yogesh', '10th', 'yb@gmail.com', 783267670)
# (4, 'sagar', '10th', 'sag@gmail.com', 783267670)
# (5, 'sachin', '10th', 'sachin@gmail.com', 783267670)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 783267670)
# (7, 'abhishek', '10th', 'abhishek@gmail.com', 783267670)

# %%
mycursor.execute("select name, email from students")
for x in mycursor:  print(x)
# Out:
# ('yogesh', 'yb@gmail.com')
# ('yogesh', 'yb@gmail.com')
# ('yogesh', 'yb@gmail.com')
# ('sagar', 'sag@gmail.com')
# ('sachin', 'sachin@gmail.com')
# ('satyarth', 'satyarth@gmail.com')
# ('abhishek', 'abhishek@gmail.com')
