# %%
import mysql.connector
mydb = mysql.connector.connect(
    host="localhost",
    user="root",
    password = "root",
    database = "mydatabase"
)
mycursor = mydb.cursor("""update students set name = 'satyarth' where name = 'sagar'""")
mydb.commit()
print(mycursor.rowcount, "record(s) affected")
# Out:
# -1 record(s) affected

# %%
mycursor = mydb.cursor()
up_data = "update students set phone = %s where phone = %s "
k = ("37294329", "783236767")
mycursor.execute(up_data, k)

# %%
mycursor.execute("select * from students")
for x in mycursor:
  print(x)
# Out:
# (3, 'yogesh', '10th', 'yb@gmail.com', 37294329)
# (4, 'sagar', '10th', 'sag@gmail.com', 37294329)
# (5, 'sachin', '10th', 'sachin@gmail.com', 37294329)
# (6, 'satyarth', '10th', 'satyarth@gmail.com', 37294329)
# (7, 'abhishek', '10th', 'abhishek@gmail.com', 37294329)
